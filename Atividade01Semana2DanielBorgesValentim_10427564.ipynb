# %% [markdown]
# ## **Instalando Pandas**

# %%
# !pip install pandas

# %% [markdown]
# ## **Importando Pandas**

# %%
import pandas as pd

# %% [markdown]
# ## **Lendo Dataframe**

# %%
df = pd.read_csv("diabetes.csv")

# %% [markdown]
# ## **Pegando amostra do Dataframe**

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## **Pegando informações sobre as features**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## **Calculando valor das features**

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ## **Pegando linhas e colunas**

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# ## **Renomeando features**

# %%
df.rename(columns = {"Pregnancies" : "Gravidez",
                     "Glucose" : "Glicose",
                     "BloodPressure" : "PressaoSanguinea",
                     "SkinThickness" : "EspessuraDaPele",
                     "Insulin" : "Insulina",
                     "BMI" : "IndiceDeMassaCorporal",
                     "DiabetesPedigreeFunction" : "FuncaoDePedigreeDeDiabetes",
                     "Age" : "Idade",
                     "Outcome" : "VariavelResposta"},
          inplace = True)

# %% [markdown]
# ## **Pegando amostra do Dataframe**

# %%
df.head()
# Out:
#    Gravidez  Glicose  PressaoSanguinea  EspessuraDaPele  Insulina  \
# 0         6      148                72               35         0
# 1         1       85                66               29         0
# 2         8      183                64                0         0
# 3         1       89                66               23        94
# 4         0      137                40               35       168
#
#    IndiceDeMassaCorporal  FuncaoDePedigreeDeDiabetes  Idade  VariavelResposta
# 0                   33.6                       0.627     50                 1
# 1                   26.6                       0.351     31                 0
# 2                   23.3                       0.672     32                 1
# 3                   28.1                       0.167     21                 0
# 4                   43.1                       2.288     33                 1

# %% [markdown]
# ## **Calculando valor das features**

# %%
df.describe()
# Out:
#          Gravidez     Glicose  PressaoSanguinea  EspessuraDaPele    Insulina  \
# count  768.000000  768.000000        768.000000       768.000000  768.000000
# mean     3.845052  120.894531         69.105469        20.536458   79.799479
# std      3.369578   31.972618         19.355807        15.952218  115.244002
# min      0.000000    0.000000          0.000000         0.000000    0.000000
# 25%      1.000000   99.000000         62.000000         0.000000    0.000000
# 50%      3.000000  117.000000         72.000000        23.000000   30.500000
# 75%      6.000000  140.250000         80.000000        32.000000  127.250000
# max     17.000000  199.000000        122.000000        99.000000  846.000000
#
#        IndiceDeMassaCorporal  FuncaoDePedigreeDeDiabetes       Idade  \
# count             768.000000                  768.000000  768.000000
# mean               31.992578                    0.471876   33.240885
# ...

# %% [markdown]
# ## **Fazendo análise exploratória dos dados**

# %%
exploracao = {"Gravidez" : "OK",
              "Glicose" : "Analisar, Glicose com valor zerado! E valor extremamente alto!",
              "PressaoSanguinea" : "Analisar, PressaoSanguinea com valor zerado!",
              "EspessuraDaPele" : "Analisar, EspessuraDaPele com valor zerado!",
              "Insulina" : "Analisar, Insulina com valor zerado! E valor extremamente alto!",
              "IndiceDeMassaCorporal" : "Analisar, IMC com valor zerado!",
              "FuncaoDePedigreeDeDiabetes" : "OK",
              "Idade" : "OK"
              }

# %% [markdown]
# ## **Transformando o dicionário em um Dataframe e mostrando**

# %%
df2 = pd.DataFrame.from_dict(exploracao, orient='index')
df2.head(15)
# Out:
#                                                                             0
# Gravidez                                                                   OK
# Glicose                     Analisar, Glicose com valor zerado! E valor ex...
# PressaoSanguinea                 Analisar, PressaoSanguinea com valor zerado!
# EspessuraDaPele                   Analisar, EspessuraDaPele com valor zerado!
# Insulina                    Analisar, Insulina com valor zerado! E valor e...
# IndiceDeMassaCorporal                         Analisar, IMC com valor zerado!
# FuncaoDePedigreeDeDiabetes                                                 OK
# Idade                                                                      OK

# %% [markdown]
# ## **Expondo as features**

# %%
df.columns
# Out:
# Index(['Gravidez', 'Glicose', 'PressaoSanguinea', 'EspessuraDaPele',
#        'Insulina', 'IndiceDeMassaCorporal', 'FuncaoDePedigreeDeDiabetes',
#        'Idade', 'VariavelResposta'],
#       dtype='object')

# %% [markdown]
# ## **Construindo nova feature com a sintaxe do indexador**

# %%
df['Idade * Gravidez'] = (df.loc[:, 'Idade'] * df.loc[:, "Gravidez"])

# %% [markdown]
# ## **Visualizando nova feature criada**

# %%
df.head()
# Out:
#    Gravidez  Glicose  PressaoSanguinea  EspessuraDaPele  Insulina  \
# 0         6      148                72               35         0
# 1         1       85                66               29         0
# 2         8      183                64                0         0
# 3         1       89                66               23        94
# 4         0      137                40               35       168
#
#    IndiceDeMassaCorporal  FuncaoDePedigreeDeDiabetes  Idade  VariavelResposta  \
# 0                   33.6                       0.627     50                 1
# 1                   26.6                       0.351     31                 0
# 2                   23.3                       0.672     32                 1
# 3                   28.1                       0.167     21                 0
# 4                   43.1                       2.288     33                 1
#
#    Idade * Gravidez
# 0               300
# 1                31
# 2               256
# ...

# %% [markdown]
# ## **Fazendo estudo das features**

# %%
df.describe()
# Out:
#          Gravidez     Glicose  PressaoSanguinea  EspessuraDaPele    Insulina  \
# count  768.000000  768.000000        768.000000       768.000000  768.000000
# mean     3.845052  120.894531         69.105469        20.536458   79.799479
# std      3.369578   31.972618         19.355807        15.952218  115.244002
# min      0.000000    0.000000          0.000000         0.000000    0.000000
# 25%      1.000000   99.000000         62.000000         0.000000    0.000000
# 50%      3.000000  117.000000         72.000000        23.000000   30.500000
# 75%      6.000000  140.250000         80.000000        32.000000  127.250000
# max     17.000000  199.000000        122.000000        99.000000  846.000000
#
#        IndiceDeMassaCorporal  FuncaoDePedigreeDeDiabetes       Idade  \
# count             768.000000                  768.000000  768.000000
# mean               31.992578                    0.471876   33.240885
# ...
